# %%
# %load_ext watermark
# %watermark --datename --machine --python --packages matplotlib,numpy,pandas,sklearn
# Out:
# Thu Apr 02 2020
#
# CPython 3.8.2
# IPython 7.12.0
#
# matplotlib 3.1.3
# numpy 1.18.1
# pandas 1.0.1
# sklearn 0.22.2.post1
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.15.0-91-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 8
# interpreter: 64bit

# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

from IPython.core.display import HTML
from time import time

from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize

# %% [markdown]
# # Experiments

# %% [markdown]
# Define routines that load MNIST dataset and run experiments.

# %%
def create_noise(X):
    n_samples, intrinsic_dim = X.shape
    noise = np.zeros((n_samples, 100 - intrinsic_dim))
    
    for j in range(noise.shape[1]):
        noise[:, j] += X[:, np.random.randint(intrinsic_dim)]
        noise[:, j] += X[:, np.random.randint(intrinsic_dim)] * np.random.randint(1, 5)
    
    return noise


def get_data(intrinsic_dim=5, random_state=32):
    np.random.seed(random_state)
    X = np.random.randn(110_000, intrinsic_dim)
    noise = create_noise(X)
    X = np.hstack((X, noise))
    normalize(X, norm='l2', copy=False)
    return X


def run_experiment(X_train, X_test, n_neighbors):
    data_params = {'n_samples': X_train.shape[0], 'n_features': X_train.shape[1]}
    algorithms = ['auto', 'brute', 'kd_tree', 'ball_tree']
    
    train_result, test_result = {}, {}
    for algo in algorithms:
        model = NearestNeighbors(n_neighbors, algorithm=algo, n_jobs=1)
        
        if algo == 'auto':
            model.fit(X_train)
            train_result[algo] = test_result[algo] = model._fit_method
        else:
            fit_times, inf_times = [], []
            for _ in range(3):
                t0 = time()
                model.fit(X_train)
                t1 = time()
                model.kneighbors(X_test, return_distance=False)
                t2 = time()
                
                fit_times.append(t1 - t0)
                inf_times.append(t2 - t1)
            
            train_result[algo] = f'{np.mean(fit_times):.2f} sec ±{np.std(fit_times):.2f}'
            test_result[algo] = f'{np.mean(inf_times):.2f} sec ±{np.std(inf_times):.2f}'
    
    return (
        {**data_params, 'n_neighbors': n_neighbors, **train_result},
        {**data_params, 'n_neighbors': n_neighbors, **test_result}
    )


def run_experiment_2(X_train, X_test, data_params, nn_params):
    n_samples, n_features = data_params.values()
    
    model = NearestNeighbors(**nn_params, n_jobs=1)
    model.fit(X_train[:n_samples, :n_features])
    
    start = time()
    model.kneighbors(X_test[:, :n_features], return_distance=False)
    end = time()
    
    return {**data_params, **nn_params, 'time': np.mean(end - start)}

# %% [markdown]
# Define a grid of parameters to explore.

# %%
param_grid = {
    'n_samples': [10_000, 100_000],
    'n_features': [5, 10, 15, 30],
    'n_neighbors': [10, 150],
}

# %% [markdown]
# Run all the experiments and split train/test results.

# %%
# %%time

X = get_data(intrinsic_dim=5)
X_train, X_test = X[:100_000, :], X[-10_000:, :]

raw_results = [
    run_experiment(
        X_train[:n_samples, :n_features],
        X_test[:, :n_features],
        n_neighbors
    )
    for n_samples, n_features, n_neighbors in \
    itertools.product(*param_grid.values())
]

train_results, test_results = zip(*raw_results)
# Out:
# CPU times: user 12min 6s, sys: 3min 59s, total: 16min 5s
# Wall time: 8min 36s

# %% [markdown]
# Define another grid of parameters where only `n_features` evolves from 2 to 100. `n_samples` and `n_neighbors` are respectively fixed to 10,000 and 10.

# %%
param_grid = {
    'n_samples': [10_000],
    'n_features': list(range(2, 101)),
    'algorithm': ['brute', 'kd_tree', 'ball_tree'],
    'n_neighbors': [10],
}

param_gen = (
    (
        {'n_samples': n_samples, 'n_features': n_features},
        {'algorithm': algorithm, 'n_neighbors': n_neighbors}
    )
    for n_samples, n_features, algorithm, n_neighbors in \
    itertools.product(*param_grid.values())
)

# %% [markdown]
# Run all the experiments.

# %%
# %%time

test_results_2 = [
    run_experiment_2(X_train, X_test, data_params, nn_params)
    for data_params, nn_params in param_gen
]
# Out:
# CPU times: user 6min 44s, sys: 1min 40s, total: 8min 25s
# Wall time: 5min 11s

# %% [markdown]
# # Results

# %% [markdown]
# Define routines to display the results.

# %%
def highlight_min_max(x):
    x = x.map(lambda x: float(x.split(' sec')[0]))
    
    is_max = x == x.max()
    is_min = x == x.min()
    
    min_color = 'background-color: lightgreen'
    max_color = 'background-color: lightcoral'
    
    return [
        min_color if val_is_min else max_color if val_is_max else ""
        for val_is_min, val_is_max in zip(is_min, is_max)
    ]


def style(results):
    results = pd.DataFrame(results).drop('n_neighbors', axis=1)
    results.set_index(['n_samples', 'n_features'], inplace=True)
    
    to_highlight = results.drop('auto', axis=1).columns
    styler = results.style.apply(
        highlight_min_max, subset=pd.IndexSlice[:, to_highlight], axis=1
    )
    
    return styler


def display(results, time):
    results_html = f"""
    <div align="center">
      <h3>{time} time (noisy data)</h3>
      <table style="width: 85%;">
        <tr>
          <th><h3 align="center">n_neighbors = 10</h3></th>
          <th><h3 align="center">n_neighbors = 150</h3></th>
        </tr>
        <tr>
    """
    
    for n_neighbors in [10, 150]:
        results_filtered = (
            res for res in results if res['n_neighbors'] == n_neighbors
        )
        
        results_html += f"""
        <td><center>{style(results_filtered).render()}</center></td>
        """
    
    results_html += """
        </tr>
      </table>
    </div>
    """
    
    return HTML(results_html)


def plot_n_features(results):
    data = pd.DataFrame(results)
    algorithms = ['brute', 'kd_tree', 'ball_tree']

    fig, ax = plt.subplots(figsize=(10, 5))

    for algo in algorithms:
        temp = data.query('algorithm == @algo')
        ax.plot(temp['n_features'], temp['time'])

    ax.grid()
    ax.set_yscale('log')
    ax.set_title('Querying time (noisy data)', fontsize=16)
    ax.set_xlabel('n_features', fontsize=14)
    ax.legend(labels=algorithms, loc='lower right', fontsize=14)
    ax.tick_params(axis='both', labelsize=12)

    plt.show()

# %% [markdown]
# Display 1st experiment training results.

# %%
display(train_results, time='Construction')
# Out:
#     <div align="center">
#       <h3>Construction time (noisy data)</h3>
#       <table style="width: 85%;">
#         <tr>
#           <th><h3 align="center">n_neighbors = 10</h3></th>
#           <th><h3 align="center">n_neighbors = 150</h3></th>
#         </tr>
#         <tr>
#
#         <td><center><style  type="text/css" >
#     #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row0_col1 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row0_col2 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row0_col3 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row1_col1 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row1_col2 {
#             background-color:  lightcoral;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row1_col3 {
#             background-color:  lightcoral;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row2_col1 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row2_col2 {
#             background-color:  lightcoral;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row2_col3 {
#             background-color:  lightcoral;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row3_col1 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row3_col2 {
#             background-color:  lightcoral;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row3_col3 {
#             background-color:  lightcoral;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row4_col1 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row4_col2 {
#             background-color:  lightcoral;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row5_col1 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row5_col2 {
#             background-color:  lightcoral;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row6_col1 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row6_col2 {
#             background-color:  lightcoral;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row7_col1 {
#             background-color:  lightgreen;
#         }    #T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row7_col2 {
#             background-color:  lightcoral;
#         }</style><table id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >auto</th>        <th class="col_heading level0 col1" >brute</th>        <th class="col_heading level0 col2" >kd_tree</th>        <th class="col_heading level0 col3" >ball_tree</th>    </tr>    <tr>        <th class="index_name level0" >n_samples</th>        <th class="index_name level1" >n_features</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4level0_row0" class="row_heading level0 row0" rowspan=4>10000</th>
#                         <th id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4level1_row0" class="row_heading level1 row0" >5</th>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row0_col0" class="data row0 col0" >kd_tree</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row0_col1" class="data row0 col1" >0.00 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row0_col2" class="data row0 col2" >0.00 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row0_col3" class="data row0 col3" >0.00 sec ±0.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4level1_row1" class="row_heading level1 row1" >10</th>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row1_col0" class="data row1 col0" >kd_tree</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row1_col1" class="data row1 col1" >0.00 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row1_col2" class="data row1 col2" >0.01 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row1_col3" class="data row1 col3" >0.01 sec ±0.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4level1_row2" class="row_heading level1 row2" >15</th>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row2_col0" class="data row2 col0" >kd_tree</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row2_col1" class="data row2 col1" >0.00 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row2_col2" class="data row2 col2" >0.01 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row2_col3" class="data row2 col3" >0.01 sec ±0.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4level1_row3" class="row_heading level1 row3" >30</th>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row3_col0" class="data row3 col0" >kd_tree</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row3_col1" class="data row3 col1" >0.00 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row3_col2" class="data row3 col2" >0.02 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row3_col3" class="data row3 col3" >0.02 sec ±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4level0_row4" class="row_heading level0 row4" rowspan=4>100000</th>
#                         <th id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4level1_row4" class="row_heading level1 row4" >5</th>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row4_col0" class="data row4 col0" >kd_tree</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row4_col1" class="data row4 col1" >0.00 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row4_col2" class="data row4 col2" >0.07 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row4_col3" class="data row4 col3" >0.06 sec ±0.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4level1_row5" class="row_heading level1 row5" >10</th>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row5_col0" class="data row5 col0" >kd_tree</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row5_col1" class="data row5 col1" >0.00 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row5_col2" class="data row5 col2" >0.12 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row5_col3" class="data row5 col3" >0.10 sec ±0.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4level1_row6" class="row_heading level1 row6" >15</th>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row6_col0" class="data row6 col0" >kd_tree</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row6_col1" class="data row6 col1" >0.00 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row6_col2" class="data row6 col2" >0.19 sec ±0.00</td>
#                         <td id="T_c2aec2be_74c5_11ea_b7ff_6740ee946be4row6_col3" class="data row6 col3" >0.14 sec ±0.00</td>
#             </tr>
#             <tr

# %% [markdown]
# Display 1st experiment testing results.

# %%
display(test_results, time='Querying')
# Out:
#     <div align="center">
#       <h3>Querying time (noisy data)</h3>
#       <table style="width: 85%;">
#         <tr>
#           <th><h3 align="center">n_neighbors = 10</h3></th>
#           <th><h3 align="center">n_neighbors = 150</h3></th>
#         </tr>
#         <tr>
#
#         <td><center><style  type="text/css" >
#     #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row0_col1 {
#             background-color:  lightcoral;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row0_col2 {
#             background-color:  lightgreen;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row1_col1 {
#             background-color:  lightcoral;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row1_col2 {
#             background-color:  lightgreen;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row2_col1 {
#             background-color:  lightcoral;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row2_col2 {
#             background-color:  lightgreen;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row3_col1 {
#             background-color:  lightcoral;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row3_col2 {
#             background-color:  lightgreen;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row4_col1 {
#             background-color:  lightcoral;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row4_col2 {
#             background-color:  lightgreen;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row5_col1 {
#             background-color:  lightcoral;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row5_col2 {
#             background-color:  lightgreen;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row6_col1 {
#             background-color:  lightcoral;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row6_col2 {
#             background-color:  lightgreen;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row7_col1 {
#             background-color:  lightcoral;
#         }    #T_c2be256a_74c5_11ea_b7ff_6740ee946be4row7_col2 {
#             background-color:  lightgreen;
#         }</style><table id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >auto</th>        <th class="col_heading level0 col1" >brute</th>        <th class="col_heading level0 col2" >kd_tree</th>        <th class="col_heading level0 col3" >ball_tree</th>    </tr>    <tr>        <th class="index_name level0" >n_samples</th>        <th class="index_name level1" >n_features</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level0_row0" class="row_heading level0 row0" rowspan=4>10000</th>
#                         <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level1_row0" class="row_heading level1 row0" >5</th>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row0_col0" class="data row0 col0" >kd_tree</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row0_col1" class="data row0 col1" >1.44 sec ±0.09</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row0_col2" class="data row0 col2" >0.09 sec ±0.00</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row0_col3" class="data row0 col3" >0.16 sec ±0.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level1_row1" class="row_heading level1 row1" >10</th>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row1_col0" class="data row1 col0" >kd_tree</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row1_col1" class="data row1 col1" >1.29 sec ±0.01</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row1_col2" class="data row1 col2" >0.13 sec ±0.00</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row1_col3" class="data row1 col3" >0.20 sec ±0.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level1_row2" class="row_heading level1 row2" >15</th>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row2_col0" class="data row2 col0" >kd_tree</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row2_col1" class="data row2 col1" >1.29 sec ±0.01</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row2_col2" class="data row2 col2" >0.22 sec ±0.00</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row2_col3" class="data row2 col3" >0.36 sec ±0.00</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level1_row3" class="row_heading level1 row3" >30</th>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row3_col0" class="data row3 col0" >kd_tree</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row3_col1" class="data row3 col1" >1.44 sec ±0.06</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row3_col2" class="data row3 col2" >0.41 sec ±0.00</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row3_col3" class="data row3 col3" >0.60 sec ±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level0_row4" class="row_heading level0 row4" rowspan=4>100000</th>
#                         <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level1_row4" class="row_heading level1 row4" >5</th>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row4_col0" class="data row4 col0" >kd_tree</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row4_col1" class="data row4 col1" >14.02 sec ±0.01</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row4_col2" class="data row4 col2" >0.12 sec ±0.00</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row4_col3" class="data row4 col3" >0.30 sec ±0.01</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level1_row5" class="row_heading level1 row5" >10</th>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row5_col0" class="data row5 col0" >kd_tree</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row5_col1" class="data row5 col1" >14.40 sec ±0.02</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row5_col2" class="data row5 col2" >0.31 sec ±0.02</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row5_col3" class="data row5 col3" >0.99 sec ±0.13</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level1_row6" class="row_heading level1 row6" >15</th>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row6_col0" class="data row6 col0" >kd_tree</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row6_col1" class="data row6 col1" >14.08 sec ±0.30</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row6_col2" class="data row6 col2" >0.57 sec ±0.02</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row6_col3" class="data row6 col3" >1.72 sec ±0.02</td>
#             </tr>
#             <tr>
#                                 <th id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4level1_row7" class="row_heading level1 row7" >30</th>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row7_col0" class="data row7 col0" >kd_tree</td>
#                         <td id="T_c2be256a_74c5_11ea_b7ff_6740ee946be4row7_col1" class="data row7 col1" >13.71 sec ±0.47</td>
#                         <td id="T_c2be256a_74c5_11e

# %% [markdown]
# Plot `n_features` experiments.

# %%
plot_n_features(test_results_2)
